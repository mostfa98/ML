# %%
import pandas as pd 
import numpy as np

# %%
np.random.seed(101)
data = np.random.randint(0,101,(4,3))
index = ['TX','MD','CA',"NY"]
columns = ['jan','feb','mar']

df = pd.DataFrame(data)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
# no comment needed
df = pd.DataFrame(data = data, index = index , columns=columns)
df
# Out:
#     jan  feb  mar
# TX   95   11   81
# MD   70   63   87
# CA   75    9   77
# NY   40    4   63

# %%
df.info
# Out:
# <bound method DataFrame.info of     jan  feb  mar
# TX   95   11   81
# MD   70   63   87
# CA   75    9   77
# NY   40    4   63>

# %%
# pwd (Print Working Directory): Shows the current directory you’re in.
# ls (List): Lists the files and folders in the current directory.

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df['total_bill'].dtype
# Out:
# dtype('float64')

# %%
#subset of the dataset
mycol = ['total_bill','tip']
df[mycol]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
# add new column to the datset
df['tip_prec'] = 100*df['tip']/ df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID   tip_prec
# 0  Christy Cunningham  3560325168603410    Sun2959   5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608  16.054159
# 2      Travis Walters  6011812112971322    Sun4458  16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260  13.978041
# 4        Tonya Carter  4832732618637221    Sun2251  14.680765

# %%
# np.round will show spicific number of decimals which you decide
# np.round(the output number , NO. of decimals you want to show).

df['price_per_person'] = np.round(df['total_bill'] / df['size'],2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID   tip_prec
# 0  Christy Cunningham  3560325168603410    Sun2959   5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608  16.054159
# 2      Travis Walters  6011812112971322    Sun4458  16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260  13.978041
# 4        Tonya Carter  4832732618637221    Sun2251  14.680765

# %%
# Remeber if you want a permnent ruselts you should assign 
# the the valie to variable 
df= df.drop('tip_prec' , axis=1)

# %%
df.shape
# Out:
# (244, 11)

# %%
# SET INDEX LABLE FOR THE DATASSET 
df = df.set_index("Payment ID")

# %%
# bring back the range index which is 123456....etc
df.reset_index()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# ...

# %%
# calling the first row numeric lable
df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# calling the first row using lable index
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# iloc means integer location 
# rows from NO. 0-4
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df = df.drop('Sun2959' , axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31720\585951595.py in ?()
# ----> 1 df = df.drop('Sun2959' , axis=0)
#       2 df.head()
#
# c:\Users\mhija\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5577                 weight  250.0   150.0
#    5578         falcon  speed   320.0   250.0
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#    5584             index=index,
#
# c:\Users\mhija\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4784         obj = self
#    4785
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221
# Sun9679                 6.32        Erik Smith   213140353657882

# %%
one_row = df.iloc[0]

# %%
# How to add row
df = pd.concat([df, one_row] , ignore_index=True)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner   2.0              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner   3.0              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner   3.0              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner   2.0             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner   4.0              6.15
#
#            Payer Name     CC Number Payment ID    0
# 0  Christy Cunningham  3.560325e+15    Sun2959  NaN
# 1      Douglas Tucker  4.478071e+15    Sun4608  NaN
# 2      Travis Walters  6.011812e+15    Sun4458  NaN
# 3    Nathaniel Harris  4.676138e+15    Sun5260  NaN
# 4        Tonya Carter  4.832733e+15    Sun2251  NaN

# %% [markdown]
# ### Conditional Filtering

# %%
df[df['total_bill']>40]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner   4.0             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner   4.0             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner   3.0             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch   5.0              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner   6.0              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner   3.0             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner   3.0             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner   2.0             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch   4.0             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner   4.0             12.08
#
#           Payer Name     CC Number Payment ID    0
# 59       Brian Ortiz  6.596454e+15    Sat8139  NaN
# ...

# %%
df[df['sex'] == 'Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66  Male     No  Sun  Dinner   3.0              3.45
# 2         21.01  3.50  Male     No  Sun  Dinner   3.0              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner   2.0             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner   4.0              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner   2.0              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner   2.0              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner   2.0             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner   3.0              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner   2.0             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner   2.0              8.91
#
#              Payer Name     CC Number Payment ID    0
# ...

# %%
# AND & ----BOTH COND NEED TO BE TRUE 

# OR | --- ONE COND NEED TO BE TRUE

# %%
df[ (df['total_bill'] > 30) & (df['sex'] == 'Male') ]
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58  Male     No   Sat  Dinner   4.0              9.86
# 39        31.27   5.00  Male     No   Sat  Dinner   3.0             10.42
# 44        30.40   5.60  Male     No   Sun  Dinner   4.0              7.60
# 47        32.40   6.00  Male     No   Sun  Dinner   4.0              8.10
# 56        38.01   3.00  Male    Yes   Sat  Dinner   4.0              9.50
# 59        48.27   6.73  Male     No   Sat  Dinner   4.0             12.07
# 83        32.68   5.00  Male    Yes  Thur   Lunch   2.0             16.34
# 95        40.17   4.73  Male    Yes   Fri  Dinner   4.0             10.04
# 112       38.07   4.00  Male     No   Sun  Dinner   3.0             12.69
# 141       34.30   6.70  Male     No  Thur   Lunch   6.0              5.72
# 142       41.19   5.00  Male     No  Thur   Lunch   5.0              8.24
# 156       48.17   5.00  Male     No   Sun  Dinner   6.0              8.03
# ...

# %%
options = ['Sat', 'Sun']
df[df['day'].isin(options)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner   2.0              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner   3.0              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner   3.0              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner   2.0             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner   4.0              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner   3.0             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner   3.0              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner   2.0             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner   2.0             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner   2.0              8.91
#
#              Payer Name     CC Number Payment ID    0
# ...
